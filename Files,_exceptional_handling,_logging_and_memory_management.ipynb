# %% [markdown]
# # THEORETICAL QUESTION
#
# Q1 What is the difference between interpreted and compiled languages?
#   - In interpreted language, code is executed line by line by an interpreter
#   - In compiled language, code is first converted into machine code by a compiler and then executed
#
# Q2 What is exception handling in Python?
#   - Exception handling is a mechanism used to handle runtime errors without stopping the entire program.
#   - It mainly uses :
#   try:
#     #risky code
#   execpt:
#     # handle error
#
# Q3 What is the purpose of the finally block in exception handling?
#   - The finally block contains code that always executes, whether an exception occurs or not.
#   - It is commonly used for cleanup operations, such as closing files.
#
# Q4 What is logging in Python?
#   - Logging is the process of recording information about a program's execution, such as events, errors, warnings, and debugging information.
#   -
# import logging
#
# logging.basicConfig(filename = file_name, level = logging.DEBUG
#
# Q5 What is the significance of the __del__ method in Python?
#   - __del__() is a special method that may be called when an object is about to be destroyed. It can be used for cleanup, execution timing should not be relied upon for critical resource management.
#
# Q6 What is the difference between import and from ...import in Python?
#   - import imports a module and usually requires name to access its members, from ... import imports specific members directly into the current resources.
#
#   - import math
#
# print(math.sqrt(25))
#
#   - from math import sqrt
#
# print(sqrt(25))
#
# Q7 How can you handle multiple exceptions in Python?
#   - Multiple exceptions are handled by using multiple except blocks, with each block handling a specific exception type.
#  -
#   try:
#
#     x = int(input("Enter number: "))
#     print(10 / x)
# except ValueError:
#
#     print("Invalid number")
# except ZeroDivisionError:
#
#     print("Cannot divide by zero")
#
# Q8 What is the purpose of the with statement when handling files in Python?
#   - The with statement is used for safe resource management. When working with files, it automatically closes the file after the block is completed, even if an exception occurs.
#
#   with open("data.txt", "r") as file:
#
#     data = file.read()
#
# Q9 What is the difference between multithreading and multiprocessing?
#   - Multithreading uses multiple threads within a process concurently and is useful for I/O-bound tasks.
#   - Multiprocessing uses separate processes paralley and is useful for CPU-bound tasks because each process has its own Python interpreter and memory space.
#
# Q10 What are the advantages of using logging in a program?
#   - Logging helps with debugging, error tracking, monitoring, troubleshoot, and maintainig a record of important program event.
#
# Q11 What is memory management in Python?
#   - Memory management in Python is the process of allocating, using, and releasing memory for objects.
#   - Python automatically manages much of its using its private memory manager, refrence counting, and garbage collector.
#
# Q12 What are the basic steps involved in exception handling in Python?
#   - The basic steps are :
#   - Put risky code inside try.
#   - Handles errors using except.
#   - Use else for code run when no exception occurs.
#   - Use finally for cleanup code that should run regardless of an exception.
#
# Q13 Why is memory management important in Python?
#   - Memory management is important because it helps use memory efficiently, reduces unnecessary memory consumption, and improves program performance and reliability.
#
# Q14 What is the role of try and except in exception handling?
#   - The try block contains code that may raise an exception, while the except block handles exception if it occurs.
#
# Q15 How does Python's garbage collection system work?
#   - Python primarily uses refrences counting to manage object lifetime and also has a cyclic garbage collector that detects and collects refrences that refrence counting alone cannot reclaim.
#
# Q16 What is the purpose of the else block in exception handling?
#   - The else block is executed when no exception occurs in the try block.
#
# Q17 What are the common logging levels in Python?
#   - The common logging levels are DEBUG, INFO, WARNING, ERROR and CRITICAL.
#
# Q18 What is the difference between os.fork() and multiprocessing in Python?
#   - os.fork() creates a child process by duplicating the current process and is available on Unix-like system.
#   - The multiprocessing module provides a higher-level way to create and manage processes in Python.
#
# Q19 What is the importance of closing a file in Python?
#   - Closing a file releases system resoures and ensures that buffered data is properly handled.
#
# Q20 What is the difference between file.read() and file.readline() in Python?
#   - read() reads the entire file or a specified number of characters, while readline() reads one line at a time.
#
# Q21 What is the logging module in Python used for?
#   - The logging module is Python's built-in module for recording program events such as debugging information, warning, errors, and other messages.
#
# Q22 What is the os module in Python used for in file handling?
#   - The os module provides functions for interacting with operating system, including working with files and directories.
#
# Q23 What are the challenges associated with memory management in Python?
#   - Challenges in Python memory management include high memory usage, reference cycles, retaining unnecessary objects, and memory growth in long-running applications.
#   - Example:
#
#   large_list = [1] * 10000000
#
# Q24 How do you raise an exception manually in Python?
#   - An exception can be raised manually using the raise keyword.
#   - Example:
#
#   age = -5
#
# if age < 0:
#
#     raise ValueError("Age cannot be negative")
#
# Q25 Why is it important to use multithreading in certain applications?
#   - Multithreading is useful for improving responsiveness and concurrency, especially in I/O-bound applications where tasks spend time waiting for external operations such as network or file I/O.

# %% [markdown]
# #Practical Questions

# %%
#Q1 How can you open a file for writing in Python and write a string to it?
file = open("data.txt", "w")
file.write("Hello World")
file.close()

# %%
#Q2 Write a Python program to read the contents of a file and print each line.
file = open("data.txt", "r")

for line in file:
  print(line)

file.close()
# Out:
# Hello World

# %%
#Q3 How would you handle a case where the file doesn't exist while trying to open it for reading?
try:
  file = open("data1.txt", "r")
  print(file.read())
  file.close()

except FileNotFoundError as e:
  print("File does not exist")
# Out:
# File does not exist

# %%
#Q4 Write a Python script that reads from one file and writes its content to another file.


source = open("source.txt", "w")
source.write("Hello everyone welcome to python")
source.close()

source = open("source.txt", "r")
content = source.read()
source.close()

destination = open("destination.txt", "w")
destination.write(content)
destination.close()

# %%
#Q5 How would you catch and handle division by zero error in Python?
try:
  a = 34
  b = 0
  print(a/b)
except ZeroDivisionError:
  print("Cannot Divide by zero")
# Out:
# Cannot Divide by zero

# %%
#Q6 Write a Python program that logs an error message to a log file when a division by zero exception occurs.
import logging
logging.basicConfig(filename = "error.log", level = logging.ERROR)

try:
  result = 10/0

except ZeroDivisionError:
  logging.error("Division by zero occured")
# Out:
# ERROR:root:Division by zero occured

# %%
#Q7 How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging
logging.basicConfig(level = logging.INFO)

logging.info("Program started")
logging.warning("This is a warning")
logging.error("An error occured")
# Out:
# WARNING:root:This is a warning
# ERROR:root:An error occured

# %%
#Q8 Write a program to handle a file opening error using exception handling.
try:
  file = open("data1.txt", "r")
  print(file.read())
  file.close()

except FileNotFoundError:
  print("File does not exist")
# Out:
# File does not exist

# %%
#Q9 How can you read a file line by line and store its content in a list in Python?
file = open("data.txt", "w")
file.write("Apple\n")
file.write("Banana\n")
file.write("Maong\n")
file.close()

file = open("data.txt", "r")

lines = []

for line in file:
  lines.append(line.strip())

file.close()

print(lines)
# Out:
# ['Apple', 'Banana', 'Maong']

# %%
#Q10 How can you append data to an existing file in Python?
file = open("data.txt", "a")
file.write("New data")
file.close()

# %%
#Q11 Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
try:
  dic = {101 : "Saud", 102 : "Krishna"}
  print(dic[103])

except KeyError:
  print("Key does not exist")
# Out:
# Key does not exist

# %%
#Q12 Write a program that demonstrates using multiple except blocks to handle different types of exceptions.
try:
  a = int(input("Enter number :"))
  print(a /0)

except ValueError:
  print("Please enter a number")

except ZeroDivisionError:
  print("Cannot divide by zero")
# Out:
# Enter number :abc
# Please enter a number

# %%
#Q13 How would you check if a file exists before attempting to read it in Python?
import os

if os.path.exists("file.txt"):
  file = open("file.txt", "r")
  print(file.read())
  file.close()

else:
  print("File not found")
# Out:
# File not found

# %%
#Q14 Write a program that uses the logging module to log both informational and error messages.
import logging
logging.basicConfig(filename = "app.log", level = logging.info)
logging.info("Program started")

try:
  result = 10 / 0

except ZeroDivisionError:
  logging.error("Cannot divide by zero")
# Out:
# ERROR:root:Cannot divide by zero

# %%
#Q15 Write a Python program that prints the content of a file and handles the case when the file is empty.
file = open("data.txt", "r")

content = file.read()

if content == "":
    print("File is empty")
else:
    print(content)

file.close()
# Out:
# Apple
# Banana
# Maong
# New data

# %%
#Q16 Demonstrate how to use memory profiling to check the memory usage of a small program.
import tracemalloc

tracemalloc.start()

numbers = [i for i in range(10000)]

current, peak = tracemalloc.get_traced_memory()

print("Current memory:", current)
print("Peak memory:", peak)

tracemalloc.stop()
# Out:
# Current memory: 398421
# Peak memory: 418774

# %%
#Q17 Write a Python program to create and write a list of numbers to a file, one number per line.
numbers = [10, 20, 30, 40, 50]

file = open("numbers.txt", "w")

for number in numbers:
    file.write(str(number) + "\n")

file.close()

# %%
#Q18 How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler

handler = RotatingFileHandler(
    "app.log",
    maxBytes=1024 * 1024,
    backupCount=3
)

logging.basicConfig(
    handlers=[handler],
    level=logging.INFO
)

logging.info("Program started")
logging.error("An error occurred")
# Out:
# ERROR:root:An error occurred

# %%
#Q19 Write a program that handles both IndexError and KeyError using a try-except block.
numbers = [10, 20, 30]
student = {"name": "Saud"}

try:
    print(numbers[2])
    print(student["age"])

except IndexError:
    print("Invalid list index")

except KeyError:
    print("Key does not exist")
# Out:
# 30
# Key does not exist

# %%
#Q20 How would you open a file and read its contents using a context manager in Python?
with open("data.txt", "r") as file:
    content = file.read()

print(content)
# Out:
# Apple
# Banana
# Maong
# New data

# %%
#Q21 Write a Python program that reads a file and prints the number of occurrences of a specific word.
with open("data.txt", "r") as file:
    content = file.read()

word = "Apple"

count = content.count(word)

print("Occurrences:", count)
# Out:
# Occurrences: 1

# %%
#Q22 How can you check if a file is empty before attempting to read its content?
with open("data.txt", "r") as file:
    content = file.read()

if content:
    print("File is not empty")
else:
    print("File is empty")
# Out:
# File is not empty

# %%
#Q23 Write a Python program that writes to a log file when an error occurs during file handling.
import logging

logging.basicConfig(
    filename="error.log",
    level=logging.ERROR
)

try:
    with open("data.txt", "r") as file:
        content = file.read()

    print(content)

except FileNotFoundError:
    logging.error("File not found")
    print("File does not exist")
# Out:
# Apple
# Banana
# Maong
# New data
